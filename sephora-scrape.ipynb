# %%
# !python sephora_perfume_scraper.py --headless --max 636 --out sephora_perfumes.csv --images-dir images
# Out:
# Found 231 product links on the listing page.
# requests error for https://www.sephora.com/product/subscription-same-day-unlimited-P483900: 403 Client Error: Forbidden for url: https://www.sephora.com/product/subscription-same-day-unlimited-P483900
# Failed to download image https://www.sephora.com/productimages/sku/sundefined-main-zoom.jpg?imwidth=50: 404 Client Error: Not Found for url: https://www.sephora.com/productimages/sku/sundefined-main-zoom.jpg?imwidth=50
# requests error for https://www.sephora.com/shop/gifts: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts
# requests error for https://www.sephora.com/shop/value-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/value-sets
# requests error for https://www.sephora.com/shop/gifts-under-10: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-under-10
# requests error for https://www.sephora.com/shop/gifts-under-15: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-under-15
# requests error for https://www.sephora.com/shop/gifts-under-25: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-under-25
# requests error for https://www.sephora.com/shop/gifts-under-50: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-under-50
# requests error for https://www.sephora.com/shop/gifts-under-75: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-under-75
# requests error for https://www.sephora.com/shop/gifts-under-100: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-under-100
# requests error for https://www.sephora.com/shop/makeup-gift-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup-gift-sets
# requests error for https://www.sephora.com/shop/skin-care-gift-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/skin-care-gift-sets
# requests error for https://www.sephora.com/shop/hair-gift-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/hair-gift-sets
# requests error for https://www.sephora.com/shop/fragrance-gift-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/fragrance-gift-sets
# requests error for https://www.sephora.com/shop/home-fragrance-candle-gift-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/home-fragrance-candle-gift-sets
# requests error for https://www.sephora.com/shop/beauty-tool-gifts: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/beauty-tool-gifts
# requests error for https://www.sephora.com/shop/makeup-bags-accessories-by-category-gifts: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup-bags-accessories-by-category-gifts
# requests error for https://www.sephora.com/shop/bath-set-gifts: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/bath-set-gifts
# requests error for https://www.sephora.com/shop/gifts-for-her: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-for-her
# requests error for https://www.sephora.com/shop/gifts-for-mom: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-for-mom
# requests error for https://www.sephora.com/shop/gifts-for-men: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-for-men
# requests error for https://www.sephora.com/shop/gifts-for-them: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/gifts-for-them
# requests error for https://www.sephora.com/shop/top-beauty-gifts: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/top-beauty-gifts
# requests error for https://www.sephora.com/shop/travel-size-toiletries: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/travel-size-toiletries
# requests error for https://www.sephora.com/shop/exclusive-products: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/exclusive-products
# requests error for https://www.sephora.com/shop/luxury-beauty: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/luxury-beauty
# requests error for https://www.sephora.com/shop/fsa-eligible-products: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/fsa-eligible-products
# requests error for https://www.sephora.com/shop/makeup-cosmetics: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup-cosmetics
# requests error for https://www.sephora.com/shop/face-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/face-makeup
# requests error for https://www.sephora.com/shop/foundation-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/foundation-makeup
# requests error for https://www.sephora.com/shop/bb-cc-cream-face-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/bb-cc-cream-face-makeup
# requests error for https://www.sephora.com/shop/tinted-moisturizer: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/tinted-moisturizer
# requests error for https://www.sephora.com/shop/concealer: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/concealer
# requests error for https://www.sephora.com/shop/makeup-primer-face-primer: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup-primer-face-primer
# requests error for https://www.sephora.com/shop/setting-powder-face-powder: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/setting-powder-face-powder
# requests error for https://www.sephora.com/shop/luminizer-luminous-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/luminizer-luminous-makeup
# requests error for https://www.sephora.com/shop/contour-palette-brush: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/contour-palette-brush
# requests error for https://www.sephora.com/shop/color-correcting: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/color-correcting
# requests error for https://www.sephora.com/shop/complexion-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/complexion-sets
# requests error for https://www.sephora.com/shop/eye-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/eye-makeup
# requests error for https://www.sephora.com/shop/eyeshadow-palettes: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/eyeshadow-palettes
# requests error for https://www.sephora.com/shop/mascara: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/mascara
# requests error for https://www.sephora.com/shop/eyeliner: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/eyeliner
# requests error for https://www.sephora.com/shop/eyebrow-makeup-pencils: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/eyebrow-makeup-pencils
# requests error for https://www.sephora.com/shop/fake-eyelashes-false-eyelashes: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/fake-eyelashes-false-eyelashes
# requests error for https://www.sephora.com/shop/eyeshadow: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/eyeshadow
# requests error for https://www.sephora.com/shop/eyeshadow-primer-eye-primer: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/eyeshadow-primer-eye-primer
# requests error for https://www.sephora.com/shop/eye-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/eye-sets
# requests error for https://www.sephora.com/shop/lips-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lips-makeup
# requests error for https://www.sephora.com/shop/lip-gloss: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lip-gloss
# requests error for https://www.sephora.com/shop/lipstick: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lipstick
# requests error for https://www.sephora.com/shop/lip-oil: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lip-oil
# requests error for https://www.sephora.com/shop/lip-plumper: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lip-plumper
# requests error for https://www.sephora.com/shop/lip-balm-treatments-lips-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lip-balm-treatments-lips-makeup
# requests error for https://www.sephora.com/shop/liquid-lipstick: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/liquid-lipstick
# requests error for https://www.sephora.com/shop/lip-liner-lip-pencils: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lip-liner-lip-pencils
# requests error for https://www.sephora.com/shop/lip-stain: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lip-stain
# requests error for https://www.sephora.com/shop/lip-palettes-gloss-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/lip-palettes-gloss-sets
# requests error for https://www.sephora.com/shop/cheek-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/cheek-makeup
# requests error for https://www.sephora.com/shop/blush: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/blush
# requests error for https://www.sephora.com/shop/bronzer-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/bronzer-makeup
# requests error for https://www.sephora.com/shop/cheek-palettes: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/cheek-palettes
# requests error for https://www.sephora.com/shop/makeup-kits-makeup-sets: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup-kits-makeup-sets
# requests error for https://www.sephora.com/shop/makeup-palettes: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup-palettes
# requests error for https://www.sephora.com/shop/makeup-applicators: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup-applicators
# requests error for https://www.sephora.com/shop/nails-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/nails-makeup
# requests error for https://www.sephora.com/shop/clean-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/clean-makeup
# requests error for https://www.sephora.com/shop/vegan-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/vegan-makeup
# requests error for https://www.sephora.com/shop/mini-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/mini-makeup
# requests error for https://www.sephora.com/shop/luxury-makeup: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/luxury-makeup
# requests error for https://www.sephora.com/shop/skincare: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/skincare
# requests error for https://www.sephora.com/shop/moisturizing-cream-oils-mists: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/moisturizing-cream-oils-mists
# requests error for https://www.sephora.com/shop/face-creams: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/face-creams
# requests error for https://www.sephora.com/shop/night-cream: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/night-cream
# requests error for https://www.sephora.com/shop/cleansing-oil-face-oil: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/cleansing-oil-face-oil
# requests error for https://www.sephora.com/shop/face-mist-face-spray: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/face-mist-face-spray
# requests error for https://www.sephora.com/shop/bb-cream-cc-cream: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/bb-cream-cc-cream
# requests error for https://www.sephora.com/shop/cleanser: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/cleanser
# requests error for https://www.sephora.com/shop/face-wash-facial-cleanser: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/face-wash-facial-cleanser
# requests error for https://www.sephora.com/shop/exfoliating-scrub-exfoliator: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/exfoliating-scrub-exfoliator
# requests error for https://www.sephora.com/shop/makeup-remover-skincare: 403 Client Error: Forbidden for url: https://www.sephora.com/shop/makeup
# Products:  89%|████████▊ | 205/231 [05:02<00:36,  1.42s/it]
# Products:  89%|████████▉ | 206/231 [05:04<00:35,  1.41s/it]
# Products:  90%|████████▉ | 207/231 [05:05<00:33,  1.40s/it]
# Products:  90%|█████████ | 208/231 [05:06<00:32,  1.42s/it]
# Products:  90%|█████████ | 209/231 [05:08<00:30,  1.40s/it]
# Products:  91%|█████████ | 210/231 [05:09<00:29,  1.39s/it]
# Products:  91%|█████████▏| 211/231 [05:11<00:27,  1.37s/it]
# Products:  92%|█████████▏| 212/231 [05:12<00:26,  1.37s/it]
# Products:  92%|█████████▏| 213/231 [05:14<00:27,  1.52s/it]
# Products:  93%|█████████▎| 214/231 [05:16<00:27,  1.60s/it]
# Products:  93%|█████████▎| 215/231 [05:17<00:26,  1.65s/it]
# Products:  94%|█████████▎| 216/231 [05:19<00:25,  1.68s/it]
# Products:  94%|█████████▍| 217/231 [05:21<00:22,  1.61s/it]
# Products:  94%|█████████▍| 218/231 [05:22<00:20,  1.54s/it]
# Products:  95%|█████████▍| 219/231 [05:35<01:01,  5.12s/it]
# Products:  95%|█████████▌| 220/231 [05:37<00:44,  4.02s/it]
# Products:  96%|█████████▌| 221/231 [05:38<00:32,  3.25s/it]
# Products:  96%|█████████▌| 222/231 [05:40<00:24,  2.69s/it]
# Products:  97%|█████████▋| 223/231 [05:41<00:18,  2.30s/it]
# Products:  97%|█████████▋| 224/231 [05:42<00:14,  2.01s/it]
# Products:  97%|█████████▋| 225/231 [05:44<00:10,  1.83s/it]
# Products:  98%|█████████▊| 226/231 [05:45<00:08,  1.70s/it]
# Products:  98%|█████████▊| 227/231 [05:47<00:06,  1.64s/it]
# Products:  99%|█████████▊| 228/231 [05:48<00:04,  1.58s/it]
# Products:  99%|█████████▉| 229/231 [06:13<00:17,  8.66s/it]
# Products: 100%|█████████▉| 230/231 [06:38<00:13, 13.42s/it]
# Products: 100%|██████████| 231/231 [07:01<00:00, 16.45s/it]
# Products: 100%|██████████| 231/231 [07:01<00:00,  1.83s/it]

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.35.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio~=0.30.0 (from selenium)
#   Downloading trio-0.30.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.6.15 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from selenium) (2025.8.3)
# Collecting typing_extensions~=4.14.0 (from selenium)
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: websocket-client~=1.8.0 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from trio~=0.30.0->selenium) (24.3.0)
# Collecting sortedcontainers (from trio~=0.30.0->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from trio~=0.30.0->selenium) (3.7)
# Collecting outcome (from trio~=0.30.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from trio~=0.30.0->selenium) (1.17.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from cffi>=1.14->trio~=0.30.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\school\miniconda3\envs\ds6001\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.35.0-py3-none-any.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ------------------- -------------------- 4.7/9.6 MB 25.9 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 28.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 22.8 MB/s eta 0:00:00
# Downloading trio-0.30.0-py3-none-any.whl (499 kB)
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, typing_extensions, outcome, trio, trio-websocket, selenium
#
#    ---------------------------------------- 0/7 [sortedcontainers]
#   Attempting uninstall: typing_extensions
#    ---------------------------------------- 0/7 [sortedcontainers]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#     Found existing installation: typing_extensions 4.15.0
#    ----------- ---------------------------- 2/7 [typing_extensions]
#     Uninstalling typing_extensions-4.15.0:
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#       Successfully uninstalled typing_extensions-4.15.0
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------- ---------------------------- 2/7 [typing_extensions]
#    ----------------- ---------------------- 3/7 [outcome]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------- ----------------- 4/7 [trio]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------- ----- 6/7 [selenium]
#    ---------------------------------------- 7/7 [selenium]
#
# Successfully installed outcome-1.3.0.post0 selenium-4.35.0 sortedcontainers-2.4.0 trio-0.30.0 trio-websocket-0.12.2 typing_extensions-4.14.1 wsproto-1.2.0

# %%
python parse_sephora_listing.py --url "https://www.sephora.com/shop/perfume?ref=filters[sizeRefinement]=mini,filters[sizeRefinement]=value,filters[sizeRefinement]=refill" --out sephora_perfumes.csv
# Out:
#   Cell In[8], line 1
#     python parse_sephora_listing.py --url "https://www.sephora.com/shop/perfume?ref=filters[sizeRefinement]=mini,filters[sizeRefinement]=value,filters[sizeRefinement]=refill" --out sephora_perfumes.csv
#            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
useragent = f'ds6001rt/0.0 (rde6mn@virginia.edu) python-requests/{requests.__version__}'
useragent
# Out:
# 'ds6001rt/0.0 (rde6mn@virginia.edu) python-requests/2.32.4'

# %%
headers = {'User-Agent': useragent, 'From': 'rde6mn@virginia.edu'}

# %%
url = "https://www.ulta.com/shop/fragrance/womens-fragrance/perfume"

# %%
r = requests.get(url, headers=headers)
r
# Out:
# <Response [200]>

# %%
mysoup = BeautifulSoup(r.text, 'html.parser')

# %%
products = mysoup.find_all("li", class_="ProductListingResults__productCard")

# %%
data = []
for p in products:
    link_tag = p.find("a", class_="pal-c-Link")
    if not link_tag:
        continue

    # Perfume link
    link = link_tag.get("href")
    if link and link.startswith("/"):
        link = "https://www.ulta.com" + link

    # Image (direct text src, not loaded later)
    img_tag = p.find("img")
    img_src = img_tag.get("src") if img_tag else None

    # Brand
    brand_tag = p.find("span", class_="ProductCard__brand")
    brand = brand_tag.get_text(strip=True) if brand_tag else None

    # Product name
    product_tag = p.find("span", class_="ProductCard__product")
    product_name = product_tag.get_text(strip=True) if product_tag else None

    # Price
    price_tag = p.find("div", class_="ProductPricing")
    price = price_tag.get_text(strip=True) if price_tag else None

    data.append({
        "Brand": brand,
        "Product": product_name,
        "Price": price,
        "Image_Link": img_src,
        "Product_Link": link
    })

df = pd.DataFrame(data)
print(df.head())
# Out:
#                  Brand                                  Product  \
# 0  Yves Saint LaurentÂ        Black Opium Eau de Parfum Glitter
# 1         Marc JacobsÂ  Daisy Love Eau So Sweet Eau de Toilette
# 2           ValentinoÂ         Donna Born In Roma Eau de Parfum
# 3       Billie EilishÂ                     Eilish Eau de Parfum
# 4  Yves Saint LaurentÂ                      MYSLF Eau de Parfum
#
#                Price                                         Image_Link  \
# 0   $99.00 - $172.00  ......
# 1   $82.00 - $142.00  ......
# 2  $110.00 - $180.00  ......
# 3    $58.00 - $78.00  ......
# 4   $99.00 - $182.00  ......
#
#                                         Product_Link
# 0  https://www.ulta.com/p/black-opium-eau-de-parf...
# 1  https://www.ulta.com/p/daisy-love-eau-so-sweet...
# 2  https://www.ulta.com/p/donna-born-in-roma-eau-...
# 3  https://www.ulta.com/p/eilish-eau-de-parfum-pi...
# 4  https://www.ulta.com/p/myslf-eau-de-parfum-pim...

# %%
df.to_csv("ulta_perfumes.csv", index=False)

# %%
df
# Out:
#                   Brand                                        Product  \
# 0   Yves Saint LaurentÂ              Black Opium Eau de Parfum Glitter
# 1          Marc JacobsÂ        Daisy Love Eau So Sweet Eau de Toilette
# 2            ValentinoÂ               Donna Born In Roma Eau de Parfum
# 3        Billie EilishÂ                           Eilish Eau de Parfum
# 4   Yves Saint LaurentÂ                            MYSLF Eau de Parfum
# ..                  ...                                            ...
# 59              ARMANIÂ                   Acqua di Gioia Eau de Parfum
# 60    Carolina HerreraÂ                   Very Good Girl Eau de Parfum
# 61       Billie EilishÂ                        Your Turn Eau de Parfum
# 62              CHANELÂ  COCO MADEMOISELLE Eau de Parfum Intense Spray
# 63          Jimmy ChooÂ                          I Want Choo Le Parfum
#
#                 Price                                         Image_Link  \
# 0    $99.00 - $172.00  ......
# 1    $82.00 - $142.00  ......
# 2   $110.00 - $180.00  ......
# 3     $58.00 - $78.00  ......
# 4    $99.00 - $182.00  ......
# ..                ...                                                ...
# 59   $75.00 - $140.00  ......
# 60  $102.00 - $176.00  ......
# 61    $70.00 - $90.00  ......
# 62  $147.00 - $182.00  ......
# 63  $100.00 - $170.00  ......
#
#                                          Product_Link
# 0   https://www.ulta.com/p/black-opium-eau-de-parf...
# 1   https://www.ulta.com/p/daisy-love-eau-so-sweet...
# 2   https://www.ulta.com/p/donna-born-in-roma-eau-...
# 3   https://www.ulta.com/p/eilish-eau-de-parfum-pi...
# 4   https://www.ulta.com/p/myslf-eau-de-parfum-pim...
# ..                                                ...
# 59  https://www.ulta.com/p/acqua-di-gioia-eau-de-p...
# 60  https://www.ulta.com/p/very-good-girl-eau-de-p...
# 61  https://www.ulta.com/p/your-turn-eau-de-parfum...
# 62  https://www.ulta.com/p/coco-mademoiselle-eau-d...
# 63  https://www.ulta.com/p/i-want-choo-le-parfum-p...
#
# [64 rows x 5 columns]

# %%
data = []

def extract_product(card):
    # Perfume link (if present)
    link_tag = card.find("a", class_="pal-c-Link")
    link = link_tag.get("href") if link_tag else None
    if link and link.startswith("/"):
        link = "https://www.ulta.com" + link

    # Image (check src, data-src, srcset)
    img_tag = card.find("img")
    img_src = None
    if img_tag:
        img_src = img_tag.get("src")
        if (img_src and img_src.startswith("data:")) or not img_src:
            img_src = img_tag.get("data-src") or img_tag.get("srcset")

    # Brand
    brand_tag = card.find("span", class_="ProductCard__brand")
    brand = brand_tag.get_text(strip=True) if brand_tag else None

    # Product name
    product_tag = card.find("span", class_="ProductCard__product")
    product_name = product_tag.get_text(strip=True) if product_tag else None

    # Price
    price_tag = card.find("div", class_="ProductPricing")
    price = price_tag.get_text(strip=True) if price_tag else None

    if brand or product_name:  # ensure it's valid
        return {
            "Brand": brand,
            "Product": product_name,
            "Price": price,
            "Image_Link": img_src,
            "Product_Link": link
        }
    return None


# --- Case 1: li-based product cards ---
cards1 = mysoup.find_all("li", class_="ProductListingResults__productCard")
for c in cards1:
    prod = extract_product(c)
    if prod:
        data.append(prod)

# --- Case 2: div-based product cards (your second example) ---
cards2 = mysoup.find_all("div", class_="ProductCard__content")
for c in cards2:
    prod = extract_product(c.parent)  # parent holds image + content
    if prod:
        data.append(prod)

# Create DataFrame and drop duplicates
df = pd.DataFrame(data).drop_duplicates(subset=["Brand", "Product"]).reset_index(drop=True)

print(df.head())
print("Total unique perfumes:", len(df))
# Out:
#                  Brand                                  Product  \
# 0  Yves Saint LaurentÂ        Black Opium Eau de Parfum Glitter
# 1         Marc JacobsÂ  Daisy Love Eau So Sweet Eau de Toilette
# 2           ValentinoÂ         Donna Born In Roma Eau de Parfum
# 3       Billie EilishÂ                     Eilish Eau de Parfum
# 4  Yves Saint LaurentÂ                      MYSLF Eau de Parfum
#
#                Price Image_Link  \
# 0   $99.00 - $172.00       None
# 1   $82.00 - $142.00       None
# 2  $110.00 - $180.00       None
# 3    $58.00 - $78.00       None
# 4   $99.00 - $182.00       None
#
#                                         Product_Link
# 0  https://www.ulta.com/p/black-opium-eau-de-parf...
# 1  https://www.ulta.com/p/daisy-love-eau-so-sweet...
# 2  https://www.ulta.com/p/donna-born-in-roma-eau-...
# 3  https://www.ulta.com/p/eilish-eau-de-parfum-pi...
# 4  https://www.ulta.com/p/myslf-eau-de-parfum-pim...
# Total unique perfumes: 64

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = "https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page={}"


data = []

def extract_product(card):
    # Perfume link (if present)
    link_tag = card.find("a", class_="pal-c-Link")
    link = link_tag.get("href") if link_tag else None
    if link and link.startswith("/"):
        link = "https://www.ulta.com" + link

    # Image (check src, data-src, srcset)
    img_tag = card.find("img")
    img_src = None
    if img_tag:
        img_src = img_tag.get("src")
        if (img_src and img_src.startswith("data:")) or not img_src:
            img_src = img_tag.get("data-src") or img_tag.get("srcset")

    # Brand
    brand_tag = card.find("span", class_="ProductCard__brand")
    brand = brand_tag.get_text(strip=True) if brand_tag else None

    # Product name
    product_tag = card.find("span", class_="ProductCard__product")
    product_name = product_tag.get_text(strip=True) if product_tag else None

    # Price
    price_tag = card.find("div", class_="ProductPricing")
    price = price_tag.get_text(strip=True) if price_tag else None

    if brand or product_name:  # ensure it's valid
        return {
            "Brand": brand,
            "Product": product_name,
            "Price": price,
            "Image_Link": img_src,
            "Product_Link": link
        }
    return None


# --- Loop through pages 1–11 ---
for page in range(1, 12):
    url = base_url.format(page)
    print(f"Scraping {url} ...")

    r = requests.get(url, headers=headers)
    soup = BeautifulSoup(r.text, "html.parser")

    # Case 1: li-based product cards
    cards1 = soup.find_all("li", class_="ProductListingResults__productCard")
    for c in cards1:
        prod = extract_product(c)
        if prod:
            data.append(prod)

    # Case 2: div-based product cards
    cards2 = soup.find_all("div", class_="ProductCard__content")
    for c in cards2:
        prod = extract_product(c.parent)
        if prod:
            data.append(prod)

    time.sleep(1)  # be polite, avoid hammering server


# --- Build DataFrame ---
df = pd.DataFrame(data).drop_duplicates(subset=["Brand", "Product"]).reset_index(drop=True)

print(df.head())
print("Total unique perfumes scraped:", len(df))
# Out:
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=1 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=2 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=3 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=4 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=5 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=6 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=7 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=8 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=9 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=10 ...
# Scraping https://www.ulta.com/shop/fragrance/womens-fragrance/perfume?page=11 ...
#                  Brand                                  Product  \
# 0  Yves Saint LaurentÂ        Black Opium Eau de Parfum Glitter
# 1         Marc JacobsÂ  Daisy Love Eau So Sweet Eau de Toilette
# 2           ValentinoÂ         Donna Born In Roma Eau de Parfum
# 3       Billie EilishÂ                     Eilish Eau de Parfum
# 4  Yves Saint LaurentÂ                      MYSLF Eau de Parfum
#
#                Price Image_Link  \
# 0   $99.00 - $172.00       None
# 1   $82.00 - $142.00       None
# 2  $110.00 - $180.00       None
# 3    $58.00 - $78.00       None
# 4   $99.00 - $182.00       None
#
#                                         Product_Link
# 0  https://www.ulta.com/p/black-opium-eau-de-parf...
# 1  https://www.ulta.com/p/daisy-love-eau-so-sweet...
# 2  https://www.ulta.com/p/donna-born-in-roma-eau-...
# 3  https://www.ulta.com/p/eilish-eau-de-parfum-pi...
# 4  https://www.ulta.com/p/myslf-eau-de-parfum-pim...
# Total unique perfumes scraped: 680

# %%
df.to_csv("full_ulta_perfumes.csv", index=False)

# %%
BeautifulSoup("http://www.google.com")
# Out:
# C:\Users\school\AppData\Local\Temp\ipykernel_42180\2709618310.py:1: MarkupResemblesLocatorWarning: The input passed in on this line looks more like a URL than HTML or XML.
#
# If you meant to use Beautiful Soup to parse the web page found at a certain URL, then something has gone wrong. You should use an Python package like 'requests' to fetch the content behind the URL. Once you have the content as a string, you can feed that string into Beautiful Soup.
#
# However, if you want to parse some data that happens to look like a URL, then nothing has gone wrong: you are using Beautiful Soup correctly, and this warning is spurious and can be filtered. To make this warning go away, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import MarkupResemblesLocatorWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=MarkupResemblesLocatorWarning)
#
#   BeautifulSoup("http://www.google.com")
# http://www.google.com

# %%
url = "https://medium.com/towards-data-science/ethics-in-web-scraping-b96b18136f01"

# %%
r = requests.get(url)
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup.get_text()
# Out:
# 'Ethics in Web Scraping. We all scrape web data. Well, those of… | by James Densmore | TDS Archive | MediumSitemapOpen in appSign upSign inMedium LogoWriteSearchSign upSign inTDS Archive·An archive of data science, data analytics, data engineering, machine learning, and artificial intelligence writing from the former Towards Data Science Medium publication.Ethics in Web ScrapingJames Densmore3 min read·Jul 23, 2017--6ListenShareWe all scrape web data. Well, those of us who work with data do. Data scientists, marketers, data journalists, and the data curious alike. Lately, I’ve been thinking more about the ethics of the practice and have been dissatisfied by the lack of consensus on the topic.Let me be clear that I’m talking ethics not the law. The law in regards to scraping web data is complex, fuzzy and ripe for reform, but that’s another matter. It’s not that no one is thinking, or writing, about the ethics in scraping but rather that both those scraping and those being scraped can’t agree on basic principles.I’ve been on both sides. I scape data mostly for personal projects, but I’ve employed it as a form of data collection on the job as well. On the other side, I’ve wrestled over how to filter out “bots” from my own or my employer’s web logs and analytics in order to focus on real customers. It’s been a reality of life for years now, and rather than fighting it let’s just set some ground rules.Though I have no illusion that these rules are complete and absolute, they cover the key points of contention I’ve come across over the years.The Ethical ScraperI, the web scraper will live by the following principles:If you have a public API that provides the data I’m looking for, I’ll use it and avoid scraping all together.I will always provide a User Agent string that makes my intentions clear and provides a way for you to contact me with questions or concerns.I will request data at a reasonable rate. I will strive to never be confused for a DDoS attack.I will only save the data I absolutely need from your page. If all I need it OpenGraph meta-data, that’s all I’ll keep.I will respect any content I do keep. I’ll never pass it off as my own.I will look for ways to return value to you. Maybe I can drive some (real) traffic to your site or credit you in an article or post.I will respond in a timely fashion to your outreach and work with you towards a resolution.I will scrape for the purpose of creating new value from the data, not to duplicate it.The Ethical Site OwnerI, the site owner will live by the following principles:I will allow ethical scrapers to access my site as long as they are not a burden on my site’s performance.I will respect transparent User Agent strings rather than blocking them and encouraging use of scrapers masked as human visitors.I will reach out to the owner of the scraper (thanks to their ethical User Agent string) before blocking permanently. A temporary block is acceptable in the case of site performance or ethical concerns.I understand that scrapers are a reality of the open web.I will consider public APIs to provide data as an alternative to scrapers.Where Does This Leave Us?Press enter or click to view image in full sizeThe ease of scraping in PythonThe fact is, scraping data is easy. With a few lines of Python and the help of some awesome libraries such as urllib2 (or Requests if you prefer) and BeautifulSoup you can grab and parse the HTML of a page. It’s so easy in fact, that responsible use is more important than ever.Of course, scraping a few thousand blog posts for a weekend project isn’t the problem. Heck, even scraping for use in business can be done quite ethically in my opinion. It’s high volume web scraping for questionable commercial use that gets the most attention and poses the highest risk for those of us who rely on the vast data of the web to innovate, learn and create new value.With a little respect we can keep a good thing going.Thanks for reading! You can connect with me or read my o ...

# %%
soup.extract_text()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 soup.extract_text()
#
# TypeError: 'NoneType' object is not callable

# %%
soup.find_all('p')
# Out:
# [<p class="bg b ee ef eg eh ei ej ek el em eo eb"><span data-dd-action-name="Susi presentation tracker global_nav"><button class="bg b ee ef ep eg eh eq ei ej er es el et eu eo ev ew ex ey ez fa fb fc fd fe ff fg fh fi fj fk bn fl fm" data-testid="headerSignUpButton">Sign up</button></span></p>,
#  <p class="bg b ee ef eg eh ei ej ek el em eo eb"><span data-dd-action-name="Susi presentation tracker global_nav"><a class="ah ai aj fo al am an ao ap aq ar as at au av" data-discover="true" data-testid="headerSignInButton" href="/m/signin?operation=login&amp;redirect=https%3A%2F%2Fmedium.com%2Fdata-science%2Fethics-in-web-scraping-b96b18136f01&amp;source=post_page---top_nav_layout_nav-----------------------global_nav------------------" rel="noopener follow">Sign in</a></span></p>,
#  <p class="bg b ee ef eg eh ei ej ek el em eo eb"><span data-dd-action-name="Susi presentation tracker global_nav"><button class="bg b ee ef ep eg eh eq ei ej er es el et eu eo ev ew ex ey ez fa fb fc fd fe ff fg fh fi fj fk bn fl fm" data-testid="headerSignUpButton">Sign up</button></span></p>,
#  <p class="bg b ee ef eg eh ei ej ek el em eo eb"><span data-dd-action-name="Susi presentation tracker global_nav"><a class="ah ai aj fo al am an ao ap aq ar as at au av" data-discover="true" data-testid="headerSignInButton" href="/m/signin?operation=login&amp;redirect=https%3A%2F%2Fmedium.com%2Fdata-science%2Fethics-in-web-scraping-b96b18136f01&amp;source=post_page---top_nav_layout_nav-----------------------global_nav------------------" rel="noopener follow">Sign in</a></span></p>,
#  <p class="bg b hm hn bl"></p>,
#  <p class="bg b bh ab eb"><span class="ib">An archive of data science, data analytics, data engineering, machine learning, and artificial intelligence writing from the former Towards Data Science Medium publication.</span></p>,
#  <p class="bg b bh ab bl"></p>,
#  <p class="bg b ec ab eb"><span class="nb">--</span></p>,
#  <p class="bg b ec ab eb"><span class="pw-responses-count nc nd">6</span></p>,
#  <p class="bg b bh ab eb">Listen</p>,
#  <p class="bg b bh ab eb">Share</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="f9b0">We all scrape web data. Well, those of us who work with data do. Data scientists, marketers, data journalists, and the data curious alike. Lately, I’ve been thinking more about the ethics of the practice and have been dissatisfied by the lack of consensus on the topic.</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="7541">Let me be clear that I’m talking <strong class="ok jb">ethics</strong> not the law. The law in regards to scraping web data is complex, fuzzy and ripe for reform, but that’s another matter. It’s not that no one is thinking, or writing, about the ethics in scraping but rather that both those scraping and those being scraped can’t agree on basic principles.</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="c989">I’ve been on both sides. I scape data mostly for personal projects, but I’ve employed it as a form of data collection on the job as well. On the other side, I’ve wrestled over how to filter out “bots” from my own or my employer’s web logs and analytics in order to focus on real customers. It’s been a reality of life for years now, and rather than fighting it let’s just set some ground rules.</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="c8b8">Though I have no illusion that these rules are complete and absolute, they cover the key points of contention I’ve come across over the years.</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol pz on oo op qa or os hb qb ou ov he qc ox oy hh qd pa pb pc ib bl" id="12fb">I, the web scraper will live by the following principles:</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol pz on oo op qa or os hb qb ou ov he qc ox oy hh qd pa pb pc ib bl" id="6938">I, the site owner will live by the following principles:</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="3843">The fact is, scraping data is easy. With a few lines of Python and the help of some awesome libraries such as <a class="ah re" href="https://docs.python.org/2/library/urllib2.html#module-urllib2" rel="noopener ugc nofollow" target="_blank">urllib2</a> (or <a class="ah re" href="http://docs.python-requests.org/en/latest/index.html" rel="noopener ugc nofollow" target="_blank">Requests</a> if you prefer) and <a class="ah re" href="https://www.crummy.com/software/BeautifulSoup/" rel="noopener ugc nofollow" target="_blank">BeautifulSoup</a> you can grab and parse the HTML of a page. It’s so easy in fact, that responsible use is more important than ever.</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="7483">Of course, scraping a few thousand blog posts for a weekend project isn’t the problem. Heck, even scraping for use in business can be done quite ethically in my opinion. It’s high volume web scraping for questionable commercial use that gets the most attention and poses the highest risk for those of us who rely on the vast data of the web to innovate, learn and create new value.</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="b308">With a little respect we can keep a good thing going.</p>,
#  <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="83b4">Thanks for reading! You can connect with me or read my other blog posts on <a class="ah re" href="https://www.dataliftoff.com/" rel="noopener ugc nofollow" target="_blank">my website</a>.</p>,
#  <p class="bg b ec ab eb"><span class="nb">--</span></p>,
#  <p class="bg b ec ab eb"><span class="nb">--</span></p>,
#  <p class="bg b bh ab eb"><span class="pw-responses-count nc nd">6</span></p>,
#  <p class="bg b bh ab bl"><span class="ib">An archive of data science, data analytics, data engineering, machine learning, and artificial intelligence writing from the former Towards Data Science Medium publication.</span></p>,
#  <p class="bg b bh ab bl">Data Science and Data Engineering Consultant at Data Liftoff <a class="ah ai aj fo al am an ao ap aq ar as at re iu ib" href="https://www.dataliftoff.com" rel="noopener ugc nofollow">https://www.dataliftoff.com</a></p>,
#  <p class="bg b ec ab eb">Help</p>,
#  <p class="bg b ec ab eb">Status</p>,
#  <p class="bg b ec ab eb">About</p>,
#  <p class="bg b ec ab eb">Careers</p>,
#  <p class="bg b ec ab eb">Press</p>,
#  <p class="bg b ec ab eb">Blog</p>,
#  <p class="bg b ec ab eb">Privacy</p>,
#  <p class="bg b ec ab eb">Rules</p>,
#  <p class="bg b ec ab eb">Terms</p>,
#  <p class="bg b ec ab eb">Text to speech</p>]

# %%
article = soup.find_all("p", "pw-post-body-paragraph")

# %%
article[1]
# Out:
# <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="7541">Let me be clear that I’m talking <strong class="ok jb">ethics</strong> not the law. The law in regards to scraping web data is complex, fuzzy and ripe for reform, but that’s another matter. It’s not that no one is thinking, or writing, about the ethics in scraping but rather that both those scraping and those being scraped can’t agree on basic principles.</p>

# %%
article[0].find_next_sibling()
# Out:
# <p class="pw-post-body-paragraph oi oj ja ok b ol om on oo op oq or os hb ot ou ov he ow ox oy hh oz pa pb pc ib bl" id="7541">Let me be clear that I’m talking <strong class="ok jb">ethics</strong> not the law. The law in regards to scraping web data is complex, fuzzy and ripe for reform, but that’s another matter. It’s not that no one is thinking, or writing, about the ethics in scraping but rather that both those scraping and those being scraped can’t agree on basic principles.</p>

# %%
article[0].find_parent(index=1)
